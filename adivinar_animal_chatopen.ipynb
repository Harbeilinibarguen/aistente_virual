# %% [markdown]
# <a href="https://colab.research.google.com/github/Harbeilinibarguen/Asistente-virtual-/blob/main/adivinar_animal_chatopen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 3.1 MB/s eta 0:00:00
# ...

# %%
import openai
import os

openai.api_key = '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'
openai.Model.list()
# Out:
# <OpenAIObject list at 0x7cc248c09850> JSON: {
#   "object": "list",
#   "data": [
#     {
#       "id": "whisper-1",
#       "object": "model",
#       "created": 1677532384,
#       "owned_by": "openai-internal",
#       "permission": [
#         {
#           "id": "modelperm-KlsZlfft3Gma8pI6A8rTnyjs",
#           "object": "model_permission",
#           "created": 1683912666,
#           "allow_create_engine": false,
#           "allow_sampling": true,
#           "allow_logprobs": true,
#           "allow_search_indices": false,
#           "allow_view": true,
#           "allow_fine_tuning": false,
#           "organization": "*",
#           "group": null,
#           "is_blocking": false
#         }
#       ],
#       "root": "whisper-1",
#       "parent": null
#     },
#     {
#       "id": "babbage",
#       "object": "model",
#       "created": 1649358449,
#       "owned_by": "openai",
#       "permission": [
#         {
# ...

# %%
import random

def get_clue():
  words = ['elefante', 'león', 'jirafa', 'hipopótamo', 'mono']
  random_word = random.choice(words)
  prompt = 'Adivina la palabra que estoy pensando. Es un animal que vive en la selva.'
  return prompt, random_word

# %%
def check_answer(user_input, answer):
  if user_input == answer:
    return True
  return False

# %%
def give_property(animal):
  response = openai.Completion.create(
      engine = 'text-davinci-003',
      prompt = 'Dame una caracteristica del tipo animal' + animal + ', pero jamás digas el nombre del animal',
      max_tokens = 100)
  return response.choices[0].text

# %%
def play_game():
  prompt, answer = get_clue()
  print(prompt)
  while True:
    user_input = input('Ingresa tu respuesta:')
    if check_answer(user_input,answer):
      print('Correcto! La respuesta era:', answer)
      break
    else:
      print('Respuesta incorrecta. Intentalo de nuevo')
      print(give_property(answer))

# %%
play_game()
# Out:
# Adivina la palabra que estoy pensando. Es un animal que vive en la selva.
# Ingresa tu respuesta:leon
# Respuesta incorrecta. Intentalo de nuevo
#
#
# Tienen una cola prensil.
# Ingresa tu respuesta:jirafa
# Respuesta incorrecta. Intentalo de nuevo
#
#
# Los monos tienen una habilidad excepcional para el equilibrio y la navegación por árboles.
# Ingresa tu respuesta:mico
# Respuesta incorrecta. Intentalo de nuevo
#
#
# Tienen una cola prensil.
# Ingresa tu respuesta:chimpaces
# Respuesta incorrecta. Intentalo de nuevo
#
#
# Son mamíferos y tienen una habilidad única para manipular objetos con sus manos.
# Ingresa tu respuesta:humano
# Respuesta incorrecta. Intentalo de nuevo
#
#
# Son animales muy inteligentes, con una habilidad significativa para adaptarse a su entorno.
# Ingresa tu respuesta:los delfines
# Respuesta incorrecta. Intentalo de nuevo
#
#
# Los monos son conocidos por su longevidad, puediendo vivir hasta 40 años de edad en condiciones óptimas.
# ...
